# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv(r"/content/avgIQpercountry.csv")

# %%
df
# Out:
#      Rank       Country  Average IQ        Continent  CONTINENT  \
# 0       1         Japan      106.48             Asia          1
# 1       2        Taiwan      106.47             Asia          1
# 2       3     Singapore      105.89             Asia          1
# 3       4     Hong Kong      105.37             Asia          1
# 4       5         China      104.10             Asia          1
# ..    ...           ...         ...              ...        ...
# 188   189        Gambia       52.68           Africa          8
# 189   190     Guatemala       47.72  Central America          6
# 190   191       Liberia       45.07           Africa          8
# 191   192  Sierra Leone       45.07           Africa          8
# 192   193         Nepal       42.99             Asia          1
#
#      Literacy Rate  Nobel Prices  HDI (2021)  HDI REPLACE  \
# 0             0.99            29       0.925        0.925
# 1             0.96             4         NaN        0.875
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            193 non-null    int64
#  1   Country                         193 non-null    object
#  2   Average IQ                      193 non-null    float64
#  3   Continent                       193 non-null    object
#  4   CONTINENT                       193 non-null    int64
#  5   Literacy Rate                   193 non-null    float64
#  6   Nobel Prices                    193 non-null    int64
#  7   HDI (2021)                      179 non-null    float64
#  8   HDI REPLACE                     193 non-null    float64
#  9   Mean years of schooling - 2021  179 non-null    float64
#  10  MEAN YEARS OF SCHOOLING-2021    193 non-null    float64
#  11   GNI - 2021                     179 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Rank                                0
# Country                             0
# Average IQ                          0
# Continent                           0
# CONTINENT                           0
# Literacy Rate                       0
# Nobel Prices                        0
# HDI (2021)                         14
# HDI REPLACE                         0
# Mean years of schooling - 2021     14
# MEAN YEARS OF SCHOOLING-2021        0
#  GNI - 2021                        14
# GNI-2021                            0
# Population - 2023                   0
# POPULATION-2023                     0
# Unnamed: 15                       193
# Unnamed: 16                       193
# Unnamed: 17                       193
# Unnamed: 18                       187
# Unnamed: 19                       185
# dtype: int64

# %%
df["Nobel Prices"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Literacy Rate"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["HDI (2021)"].isnull().sum()
# Out:
# np.int64(14)

# %%
df[df["HDI (2021)"].isnull()]
# Out:
#      Rank                   Country  Average IQ        Continent  CONTINENT  \
# 1       2                    Taiwan      106.47             Asia          1
# 13     14                     Macao       99.82             Asia          1
# 20     21               North Korea       98.82             Asia          1
# 41     42             New Caledonia       93.92          Oceania          4
# 44     45                   Bermuda       93.48    North America          3
# 84     85  Turks and Caicos Islands       84.29  Central America          6
# 96     97            Cayman Islands       82.24  Central America          6
# 101   102               Puerto Rico       81.99  Central America          6
# 107   108  Northern Mariana Islands       81.36          Oceania          4
# 124   125                East Timor       78.49             Asia          1
# 132   133    British Virgin Islands       76.69  Central America          6
# ...

# %%
df[df["Nobel Prices"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Rank, Country, Average IQ, Continent, CONTINENT, Literacy Rate, Nobel Prices, HDI (2021), HDI REPLACE, Mean years of schooling - 2021, MEAN YEARS OF SCHOOLING-2021,  GNI - 2021, GNI-2021, Population - 2023, POPULATION-2023, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19]
# Index: []

# %%
df[df["Literacy Rate"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Rank, Country, Average IQ, Continent, CONTINENT, Literacy Rate, Nobel Prices, HDI (2021), HDI REPLACE, Mean years of schooling - 2021, MEAN YEARS OF SCHOOLING-2021,  GNI - 2021, GNI-2021, Population - 2023, POPULATION-2023, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19]
# Index: []

# %%
df["Country"].replace("Rank","rank")
# Out:
# 0             Japan
# 1            Taiwan
# 2         Singapore
# 3         Hong Kong
# 4             China
#            ...
# 188          Gambia
# 189       Guatemala
# 190         Liberia
# 191    Sierra Leone
# 192           Nepal
# Name: Country, Length: 193, dtype: object

# %%
df.head(10)
# Out:
#    Rank        Country  Average IQ Continent  CONTINENT  Literacy Rate  \
# 0     1          Japan      106.48      Asia          1           0.99
# 1     2         Taiwan      106.47      Asia          1           0.96
# 2     3      Singapore      105.89      Asia          1           0.97
# 3     4      Hong Kong      105.37      Asia          1           0.94
# 4     5          China      104.10      Asia          1           0.96
# 5     6    South Korea      102.35      Asia          1           0.98
# 6     7        Belarus      101.60    Europe          2           1.00
# 7     8        Finland      101.20    Europe          2           1.00
# 8     9  Liechtenstein      101.07    Europe          2           1.00
# 9    10        Germany      100.74    Europe          2           0.99
#
#    Nobel Prices  HDI (2021)  HDI REPLACE  Mean years of schooling - 2021  \
# 0            29       0.925        0.925                            13.4
# ...

# %%
df["Nobel Prices"]=df["Nobel Prices"].fillna(df["Nobel Prices"].mean())

# %%
df
# Out:
#      Rank       Country  Average IQ        Continent  CONTINENT  \
# 0       1         Japan      106.48             Asia          1
# 1       2        Taiwan      106.47             Asia          1
# 2       3     Singapore      105.89             Asia          1
# 3       4     Hong Kong      105.37             Asia          1
# 4       5         China      104.10             Asia          1
# ..    ...           ...         ...              ...        ...
# 188   189        Gambia       52.68           Africa          8
# 189   190     Guatemala       47.72  Central America          6
# 190   191       Liberia       45.07           Africa          8
# 191   192  Sierra Leone       45.07           Africa          8
# 192   193         Nepal       42.99             Asia          1
#
#      Literacy Rate  Nobel Prices  HDI (2021)  HDI REPLACE  \
# 0             0.99            29       0.925        0.925
# 1             0.96             4         NaN        0.875
# ...

# %%
df["Literacy Rate"]=df["Literacy Rate"].fillna(df["Literacy Rate"].mean())

# %%
df
# Out:
#      Rank       Country  Average IQ        Continent  CONTINENT  \
# 0       1         Japan      106.48             Asia          1
# 1       2        Taiwan      106.47             Asia          1
# 2       3     Singapore      105.89             Asia          1
# 3       4     Hong Kong      105.37             Asia          1
# 4       5         China      104.10             Asia          1
# ..    ...           ...         ...              ...        ...
# 188   189        Gambia       52.68           Africa          8
# 189   190     Guatemala       47.72  Central America          6
# 190   191       Liberia       45.07           Africa          8
# 191   192  Sierra Leone       45.07           Africa          8
# 192   193         Nepal       42.99             Asia          1
#
#      Literacy Rate  Nobel Prices  HDI (2021)  HDI REPLACE  \
# 0             0.99            29       0.925        0.925
# 1             0.96             4         NaN        0.875
# ...

# %%
df.head(10)
# Out:
#    Rank        Country  Average IQ Continent  CONTINENT  Literacy Rate  \
# 0     1          Japan      106.48      Asia          1           0.99
# 1     2         Taiwan      106.47      Asia          1           0.96
# 2     3      Singapore      105.89      Asia          1           0.97
# 3     4      Hong Kong      105.37      Asia          1           0.94
# 4     5          China      104.10      Asia          1           0.96
# 5     6    South Korea      102.35      Asia          1           0.98
# 6     7        Belarus      101.60    Europe          2           1.00
# 7     8        Finland      101.20    Europe          2           1.00
# 8     9  Liechtenstein      101.07    Europe          2           1.00
# 9    10        Germany      100.74    Europe          2           0.99
#
#    Nobel Prices  HDI (2021)  HDI REPLACE  Mean years of schooling - 2021  \
# 0            29       0.925        0.925                            13.4
# ...

# %%
Continent=["Asia","Europe","Africa","Central America","North America","Oceania","Europe/Asia","South America"]
Nobel_Prices=[4,5,6,8,11,12,13,19]
plt.plot( Continent,Nobel_Prices,marker="3",markersize=10,color="black",linestyle="--")
plt.title("Continent vs Nobel Prices")
plt.xlabel("Continent")
plt.ylabel("Nobel Prices")
plt.show()
